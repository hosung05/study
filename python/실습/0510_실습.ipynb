# %%
ㅠ프.ㅎ,import sys

# %%
print(sys.executable)
# Out:
# C:\Users\user\anaconda3\envs\abangues\python.exe

# %% [markdown]
# # 첫 실습
# * 주피터 연습 - 1

# %% [markdown]
# markdown

# %%
# print('test1')
print('test2')
# Out:
# test2

# %%
print('Hello world')
print("나는 홍경수입니다")
# Out:
# Hello world
# 나는 홍경수입니다

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5])
plt.ylabel('Number')
plt.show()

# %%
a = 10
b = 10

# %%
print(a)
# Out:
# 10

# %%
a = 30

# %%
while True:
    a = 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-bdae9590c512> in <module>
#       1 while True:
# ----> 2     a = 0
#
# KeyboardInterrupt:

# %%
x = input("당신의 나이를 입력해주세요")
# Out:
# 당신의 나이를 입력해주세요40

# %%
'''출력
나이
'''
""" 나이
출력"""

print(x)
# Out:
# 40

# %%
data = 1
print(data)
# Out:
# 1

# %%
print = 1

# %%
print(data)
print('test')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# TypeError: 'int' object is not callable

# %%
print(1 + 2)
# Out:
# 3

# %%
1 + 2
# Out:
# 3

# %%
1 - 2
# Out:
# -1

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
1 + 2 * 3
# Out:
# 7

# %%
(1 + 2) * 3
# Out:
# 9

# %%
type(3)
# Out:
# int

# %%
float(3)
# Out:
# 3.0

# %%
int(3.0)
# Out:
# 3

# %%
int(5/2)
# Out:
# 2

# %%
x = 20
y = 30

# %%
c = x + y
c
# Out:
# 50

# %%
x = 10
x + 10
x
# Out:
# 10

# %%
x = x + 10
x
# Out:
# 20

# %%
x += 10
x
# Out:
# 30

# %%
print = 1

# %%
print(x)
# Out:
# 30

# %%
del(print)

# %%
x = None
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
x = True
type(x)
# Out:
# bool

# %%
print(3 > 1)
# Out:
# True

# %%
print(10 != 10)
# Out:
# False

# %%
type(10 == 10)
# Out:
# bool

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
score1 = int(input('첫번째 점수'))
score2 = int(input('두번째 점수'))
score3 = int(input('세번째 점수'))
# Out:
# 첫번째 점수70
# 두번째 점수80
# 세번째 점수90

# %%
score1 > 65 and score2 > 65 and score3  > 65
# Out:
# True

# %%
first = """hello
world"""
first
# Out:
# 'hello\nworld'

# %%
"-"*20
# Out:
# '--------------------'

# %%
word = "apple banana"
word
# Out:
# 'apple banana'

# %%
len(word)
# Out:
# 12

# %%
word2 = word.upper()
print(word)
print(word2)
# Out:
# apple banana
# APPLE BANANA

# %%
word2.lower()
# Out:
# 'apple banana'

# %%
word.replace('apple', 'orange')
# Out:
# 'orange banana'

# %%
str?

# %%
name = "Tom"
print("I am " + name + "!")
# Out:
# I am Tom!

# %%
print("I am %s!" % name)
# Out:
# I am Tom!

# %%
print("I am %10s!" % name)
# Out:
# I am        Tom!

# %%
print("I am %-10s!" % name)
# Out:
# I am Tom       !

# %%
f1, f2 = "apple", "banana"
print("I like %s, %s"% (f1, f2))
# Out:
# I like apple, banana

# %%
n1, n2 = 3, 3.2323
print("n1 = %d, n2 = %f" % (n1, n2))
# Out:
# n1 = 3, n2 = 3.232300

# %%
print("n1 = %f, n2 = %d" % (n1, n2))
# Out:
# n1 = 3.000000, n2 = 3

# %%
print("n2 = %.2f" % n2)
# Out:
# n2 = 3.23

# %%
print('n2 = %07.2f' % n2)
# Out:
# n2 = 0003.23

# %%
print('n2 = %07.4f' % n2)
# Out:
# n2 = 03.2323

# %%
print("I like {0}, {1}".format('apple', 'banana'))
# Out:
# I like apple, banana

# %%
print("I like {}, {}".format('apple', 'banana'))
# Out:
# I like apple, banana

# %%
print("I like {1}, {0}".format('apple', 'banana'))
# Out:
# I like banana, apple

# %%
fruit1, fruit2 = 'apple', 'banana'

# %%
print(f"I like {fruit1}, {fruit2}")
# Out:
# I like apple, banana

# %%
print("n1 = {}, n2 = {}".format(n1, n2))
# Out:
# n1 = 3, n2 = 3.2323

# %%
print(f"I like {n1}, {n2}")
# Out:
# I like 3, 3.2323

# %%
print("n1 = {}, n2 = {:.2f}".format(n1, n2))
# Out:
# n1 = 3, n2 = 3.23
